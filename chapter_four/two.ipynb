# %%
v = {
    12: -22,
    13: -20,
    14: -14,
    15: 0
}

while True:
    difference = 0

    old_v = v[15]

    v[15] = sum([0.25 * (-1 + v[next_state]) for next_state in v.keys()])

    difference = abs(v[15] - old_v)

    if difference < 0.000001:
        break
    
    print(v[15])
# Out:
# -15.0
# -18.75
# -19.6875
# -19.921875
# -19.98046875
# -19.9951171875
# -19.998779296875
# -19.99969482421875
# -19.999923706054688
# -19.999980926513672
# -19.999995231628418
# -19.999998807907104

# %% [markdown]
# Now the next part will change the dynamics of the problem as 13 will be linked to 15. I could write a policy evaluation function. But I can notice that it will be the same as before because 13 has the same state value.
